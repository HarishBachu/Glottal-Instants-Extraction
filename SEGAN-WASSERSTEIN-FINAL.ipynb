# %%
import numpy as np
import os
import librosa
import matplotlib.pyplot as plt
import keras
from keras import layers
import keras.backend as K
from keras.layers import PReLU
from scipy.signal import butter, lfilter

# %%
dataset = r'C:\Users\user\Desktop\dataset'
egg = []
speech = []

n = 0
for i in os.listdir(dataset + r"\speech"):
    if i[:3] == "bdl":
        n += 1
        egg_sample,_ = librosa.load(dataset + r"\egg" + "\\" + i)
        speech_sample,_ = librosa.load(dataset + r"\speech" + "\\" + i)
        speech_sample = np.append(speech_sample[0], speech_sample[1:] - 0.97 * speech_sample[:-1])
        egg.append(egg_sample)
        speech.append(speech_sample)
        if n == 100:
            break
            
n = 0
for i in os.listdir(dataset + r"\speech"):
    if i[:3] == "jmk":
        n += 1
        egg_sample,_ = librosa.load(dataset + r"\egg" + "\\" + i)
        speech_sample,_ = librosa.load(dataset + r"\speech" + "\\" + i)
        speech_sample = np.append(speech_sample[0], speech_sample[1:] - 0.97 * speech_sample[:-1])
        egg.append(egg_sample)
        speech.append(speech_sample)
        if n == 100:
            break
            
n = 0
for i in os.listdir(dataset + r"\speech"):
    if i[:3] == "slt":
        n += 1
        egg_sample,_ = librosa.load(dataset + r"\egg" + "\\" + i)
        speech_sample,_ = librosa.load(dataset + r"\speech" + "\\" + i)
        speech_sample = np.append(speech_sample[0], speech_sample[1:] - 0.97 * speech_sample[:-1])
        egg.append(egg_sample)
        speech.append(speech_sample)
        if n == 100:
            break

# %%
egg_dataset = []
speech_dataset = []

window_size = 2048

for i in range(len(egg)):
    for j in range(len(egg[i])//window_size):
        egg_dataset.append(egg[i][window_size*j:window_size*(j+1)])
        speech_dataset.append(speech[i][window_size*j:window_size*(j+1)])
        
del egg,speech

# %%
egg_dataset = np.array(egg_dataset)
speech_dataset = np.array(speech_dataset)

# %%
n = len(egg_dataset)

speech_train = speech_dataset[:int(n*0.95)]
egg_train = egg_dataset[:int(n*0.95)]

speech_test = speech_dataset[int(n*0.95):]
egg_test = egg_dataset[int(n*0.95):]

del egg_dataset,speech_dataset

# %%
def define_generator(window_size):
    input_speech = keras.Input(shape=(window_size,1,))

    layer1 = layers.Conv1D(8, 32, strides = 2,padding = "same")(input_speech)
    layer1 = PReLU(alpha_initializer="zeros")(layer1)

    layer2 = layers.Conv1D(16, 32, strides = 2,padding = "same")(layer1)
    layer2 = PReLU(alpha_initializer="zeros")(layer2)
    
    layer3 = layers.Conv1D(32, 32, strides = 2,padding = "same")(layer2)
    layer3 = PReLU(alpha_initializer="zeros")(layer3)
    
    layer4 = layers.Conv1D(64, 32, strides = 2,padding = "same")(layer3)
    layer4 = PReLU(alpha_initializer="zeros")(layer4)
    
    layer5 = layers.Conv1D(128, 32, strides = 2,padding = "same")(layer4)
    layer5 = PReLU(alpha_initializer="zeros")(layer5)

    condensed = layers.Conv1D(256, 32, strides = 2,padding = "same")(layer5)
    condensed = PReLU(alpha_initializer="zeros")(condensed)
    
    upsample5 = layers.Conv1DTranspose(128, 32, strides = 2,padding = "same")(condensed)
    upsample5 = PReLU(alpha_initializer="zeros")(upsample5)
    buffer5 = layers.concatenate([upsample5,layer5])

    upsample4 = layers.Conv1DTranspose(64, 32, strides = 2,padding = "same")(buffer5)
    upsample4 = PReLU(alpha_initializer="zeros")(upsample4)
    buffer4 = layers.concatenate([upsample4,layer4])
    
    upsample3 = layers.Conv1DTranspose(32, 32, strides = 2,padding = "same")(buffer4)
    upsample3 = PReLU(alpha_initializer="zeros")(upsample3)
    buffer3 = layers.concatenate([upsample3,layer3])
    
    upsample2 = layers.Conv1DTranspose(16, 32, strides = 2,padding = "same")(buffer3)
    upsample2 = PReLU(alpha_initializer="zeros")(upsample2)
    buffer2 = layers.concatenate([upsample2,layer2])

    upsample1 = layers.Conv1DTranspose(8, 32, strides = 2,padding = "same")(buffer2)
    upsample1 = PReLU(alpha_initializer="zeros")(upsample1)
    buffer1 = layers.concatenate([upsample1,layer1])

    final_1 = layers.Conv1DTranspose(8, 32, strides = 2,padding = "same")(buffer1)
    final_1 = PReLU(alpha_initializer="zeros")(final_1)
    final_2 = layers.Conv1D(4, 32, padding = "same")(final_1)
    final_2 = PReLU(alpha_initializer="zeros")(final_2)
    final_egg = layers.Conv1D(1, 32, activation = "tanh",padding = "same")(final_2)

    autoencoder_generator = keras.Model(input_speech, final_egg)
    
    return autoencoder_generator

# %%
def wasserstein_loss(y_true,y_pred):
    return 0.1*y_pred*y_true

# %%
def define_discriminator(window_size):
    input_egg = keras.Input(shape=(window_size,1,))
    
    
    layer1 = layers.Conv1D(16, 10, activation="relu", strides = 4)(input_egg)
    layer1 = layers.BatchNormalization()(layer1)
    
    x = layers.Flatten()(layer1)
    
    x = layers.Dense(512, activation="relu")(x)
    
    x = layers.Dense(256, activation="relu")(x)
    
    x = layers.Dense(64, activation="relu")(x)
    
    out = layers.Dense(1, activation="tanh")(x)
    
    discriminator_model = keras.Model(input_egg,out)
    
    opt = keras.optimizers.RMSprop(lr=0.00005, clipvalue=0.1)

    discriminator_model.compile(loss=wasserstein_loss, optimizer=opt)
    
    return discriminator_model

# %%
def define_gan(generator, discriminator,window_size):
    input_speech = keras.Input(shape=(window_size,1,))
    
    discriminator.trainable = False
    out_generator = generator(input_speech)
    out_discriminator = discriminator(out_generator)
    
    model = keras.Model(input_speech,[out_generator,out_discriminator])
    
    opt = keras.optimizers.RMSprop(lr=0.0005)
    
    model.compile(loss = ["mae",wasserstein_loss], optimizer=opt)
    
    return model

# %%
generator = define_generator(window_size)
discriminator = define_discriminator(window_size)
gan = define_gan(generator, discriminator,window_size)

# %%
epochs = 50

y_gan = -np.ones(len(speech_train))

y_discriminator = -np.ones(len(speech_train))

y_discriminator[:len(speech_train)//2] = 1

for i in range(epochs):
    
    print("Discriminator training - Iteration - " + str(i+1))
    
    discriminator.fit(np.concatenate((generator.predict(speech_train[:len(speech_train)//2])[:,:,0],egg_train[len(speech_train)//2:])), y_discriminator,
                epochs=5,
                shuffle=True,
                batch_size=16)
    
    print("Generator training - Iteration - " + str(i+1))
    
    gan.fit(speech_train, [egg_train,y_gan],
                epochs=1,
                shuffle=True,
                batch_size=16)
    
    generator.save(r"C:\Users\user\Desktop\segan_model_7")
# Out:
# Discriminator training - Iteration - 1
# Epoch 1/5
# 580/580 [==============================] - 35s 60ms/step - loss: -0.0717
# Epoch 2/5
# 580/580 [==============================] - 35s 60ms/step - loss: -0.0956
# Epoch 3/5
# 580/580 [==============================] - 34s 59ms/step - loss: -0.0982
# Epoch 4/5
# 580/580 [==============================] - 35s 60ms/step - loss: -0.0983
# Epoch 5/5
# 580/580 [==============================] - 35s 59ms/step - loss: -0.0986
# Generator training - Iteration - 1
# 580/580 [==============================] - 134s 231ms/step - loss: -0.0574 - functional_25_loss: 0.0415 - functional_27_loss: -0.0989
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 2
# Epoch 1/5
# 580/580 [==============================] - 36s 62ms/step - loss: -0.0520
# Epoch 2/5
# 580/580 [==============================] - 36s 62ms/step - loss: -0.0645
# Epoch 3/5
# 580/580 [==============================] - 35s 61ms/step - loss: -0.0783
# Epoch 4/5
# 580/580 [==============================] - 35s 61ms/step - loss: -0.0884
# Epoch 5/5
# 580/580 [==============================] - 36s 61ms/step - loss: -0.0912
# Generator training - Iteration - 2
# 580/580 [==============================] - 136s 235ms/step - loss: -0.0572 - functional_25_loss: 0.0411 - functional_27_loss: -0.0984
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 3
# Epoch 1/5
# 580/580 [==============================] - 35s 61ms/step - loss: -0.0796
# Epoch 2/5
# 580/580 [==============================] - 35s 61ms/step - loss: -0.0961
# Epoch 3/5
# 580/580 [==============================] - 35s 60ms/step - loss: -0.0972
# Epoch 4/5
# 580/580 [==============================] - 35s 60ms/step - loss: -0.0985
# Epoch 5/5
# 580/580 [==============================] - 35s 60ms/step - loss: -0.0994
# Generator training - Iteration - 3
# 580/580 [==============================] - 136s 234ms/step - loss: -0.0595 - functional_25_loss: 0.0393 - functional_27_loss: -0.0989
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 4
# Epoch 1/5
# 580/580 [==============================] - 34s 58ms/step - loss: -0.0534
# Epoch 2/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0676
# Epoch 3/5
# 580/580 [==============================] - 34s 58ms/step - loss: -0.0728
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0806
# Epoch 5/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0877
# Generator training - Iteration - 4
# 580/580 [==============================] - 133s 230ms/step - loss: -0.0599 - functional_25_loss: 0.0385 - functional_27_loss: -0.0984
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 5
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0515
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0891
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0961
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0982
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0991
# Generator training - Iteration - 5
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0619 - functional_25_loss: 0.0373 - functional_27_loss: -0.0992
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 6
# Epoch 1/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0678
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0774
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0822
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0862
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0871
# Generator training - Iteration - 6
# 580/580 [==============================] - 132s 227ms/step - loss: -0.0612 - functional_25_loss: 0.0370 - functional_27_loss: -0.0981
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 7
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0653
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0959
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0991
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0995
# Epoch 5/5
# 580/580 [==============================] - 32s 56ms/step - loss: -0.0996
# Generator training - Iteration - 7
# 580/580 [==============================] - 133s 229ms/step - loss: -0.0626 - functional_25_loss: 0.0353 - functional_27_loss: -0.0979
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 8
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0533
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0869
# Epoch 3/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0944
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0972
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0981
# Generator training - Iteration - 8
# 580/580 [==============================] - 132s 227ms/step - loss: -0.0648 - functional_25_loss: 0.0347 - functional_27_loss: -0.0995
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 9
# Epoch 1/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0377
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0821
# Epoch 3/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0925
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0951
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0965
# Generator training - Iteration - 9
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0649 - functional_25_loss: 0.0338 - functional_27_loss: -0.0987
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 10
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0859
# Epoch 2/5
# 580/580 [==============================] - 32s 56ms/step - loss: -0.0975
# Epoch 3/5
# 580/580 [==============================] - 32s 56ms/step - loss: -0.0988
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0992
# Epoch 5/5
# 580/580 [==============================] - 32s 56ms/step - loss: -0.0993
# Generator training - Iteration - 10
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0658 - functional_25_loss: 0.0332 - functional_27_loss: -0.0989
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 11
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0814
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0950
# Epoch 3/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0964
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0968
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0973
# Generator training - Iteration - 11
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0662 - functional_25_loss: 0.0325 - functional_27_loss: -0.0987
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 12
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0762
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0949
# Epoch 3/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0981
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0986
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0991
# Generator training - Iteration - 12
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0675 - functional_25_loss: 0.0317 - functional_27_loss: -0.0992
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 13
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0690
# Epoch 2/5
# 580/580 [==============================] - 34s 58ms/step - loss: -0.0939
# Epoch 3/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0956
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0970
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0977
# Generator training - Iteration - 13
# 580/580 [==============================] - 133s 230ms/step - loss: -0.0682 - functional_25_loss: 0.0312 - functional_27_loss: -0.0993
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 14
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0581
# Epoch 2/5
# 580/580 [==============================] - 36s 62ms/step - loss: -0.0826
# Epoch 3/5
# 580/580 [==============================] - 34s 58ms/step - loss: -0.0918
# Epoch 4/5
# 580/580 [==============================] - 34s 58ms/step - loss: -0.0952
# Epoch 5/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0970
# Generator training - Iteration - 14
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0691 - functional_25_loss: 0.0303 - functional_27_loss: -0.0995
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 15
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0122
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0386
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0475
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0649
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0917
# Generator training - Iteration - 15
# 580/580 [==============================] - 132s 227ms/step - loss: -0.0685 - functional_25_loss: 0.0300 - functional_27_loss: -0.0985
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 16
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0346
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0484
# Epoch 3/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0718
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0889
# Epoch 5/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0932
# Generator training - Iteration - 16
# 580/580 [==============================] - 131s 227ms/step - loss: -0.0694 - functional_25_loss: 0.0298 - functional_27_loss: -0.0992
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 17
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0461
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0775
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0938
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0976
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0985
# Generator training - Iteration - 17
# 580/580 [==============================] - 131s 225ms/step - loss: -0.0707 - functional_25_loss: 0.0290 - functional_27_loss: -0.0997
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 18
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0337
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0483
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.05150s - loss: -0.05
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0622
# Epoch 5/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0859
# Generator training - Iteration - 18
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0714 - functional_25_loss: 0.0283 - functional_27_loss: -0.0997
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 19
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0563
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0762
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0903
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0955
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0965
# Generator training - Iteration - 19
# 580/580 [==============================] - 132s 227ms/step - loss: -0.0716 - functional_25_loss: 0.0280 - functional_27_loss: -0.0996
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 20
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0550
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0945
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0969
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0977
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0980
# Generator training - Iteration - 20
# 580/580 [==============================] - 132s 227ms/step - loss: -0.0719 - functional_25_loss: 0.0276 - functional_27_loss: -0.0995
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 21
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0623
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0771
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0851
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0916
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0940
# Generator training - Iteration - 21
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0726 - functional_25_loss: 0.0271 - functional_27_loss: -0.0998
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 22
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0779
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0951
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0968
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0979
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0982
# Generator training - Iteration - 22
# 580/580 [==============================] - 131s 225ms/step - loss: -0.0726 - functional_25_loss: 0.0268 - functional_27_loss: -0.0994
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 23
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0536
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0927
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0961
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0971
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0975
# Generator training - Iteration - 23
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0730 - functional_25_loss: 0.0264 - functional_27_loss: -0.0994
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 24
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0639
# Epoch 2/5
# 580/580 [==============================] - 34s 58ms/step - loss: -0.0949
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0975
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0984
# Epoch 5/5
# 580/580 [==============================] - 34s 58ms/step - loss: -0.0989
# Generator training - Iteration - 24
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0734 - functional_25_loss: 0.0259 - functional_27_loss: -0.0993
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 25
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0619
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0973
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0982
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0985
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0978
# Generator training - Iteration - 25
# 580/580 [==============================] - 131s 225ms/step - loss: -0.0736 - functional_25_loss: 0.0255 - functional_27_loss: -0.0992
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 26
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0877
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0997
# Epoch 3/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0997
# Epoch 4/5
# 580/580 [==============================] - 32s 56ms/step - loss: -0.0998
# Epoch 5/5
# 580/580 [==============================] - 32s 56ms/step - loss: -0.0998
# Generator training - Iteration - 26
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0745 - functional_25_loss: 0.0251 - functional_27_loss: -0.0996
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 27
# Epoch 1/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0793
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0974
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0978
# Epoch 4/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0986
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0990
# Generator training - Iteration - 27
# 580/580 [==============================] - 131s 227ms/step - loss: -0.0743 - functional_25_loss: 0.0248 - functional_27_loss: -0.0992
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 28
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0813
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0966
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0975
# Epoch 4/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0978
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0986
# Generator training - Iteration - 28
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0754 - functional_25_loss: 0.0244 - functional_27_loss: -0.0999
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 29
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0644
# Epoch 2/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0964
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0986
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0989
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0994
# Generator training - Iteration - 29
# 580/580 [==============================] - 132s 227ms/step - loss: -0.0755 - functional_25_loss: 0.0241 - functional_27_loss: -0.0997
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 30
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0816
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0977
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0990
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0991
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0992
# Generator training - Iteration - 30
# 580/580 [==============================] - 132s 227ms/step - loss: -0.0747 - functional_25_loss: 0.0240 - functional_27_loss: -0.0987
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 31
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0600
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0985
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0993
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0994
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0995
# Generator training - Iteration - 31
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0755 - functional_25_loss: 0.0238 - functional_27_loss: -0.0992
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 32
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0787
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0959
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0972
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0979
# Epoch 5/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0983
# Generator training - Iteration - 32
# 580/580 [==============================] - 131s 227ms/step - loss: -0.0759 - functional_25_loss: 0.0234 - functional_27_loss: -0.0994
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 33
# Epoch 1/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0446
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0841
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0983
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0991
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0992
# Generator training - Iteration - 33
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0762 - functional_25_loss: 0.0233 - functional_27_loss: -0.0995
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 34
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0809
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0985
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0990
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0994
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0994
# Generator training - Iteration - 34
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0765 - functional_25_loss: 0.0229 - functional_27_loss: -0.0994
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 35
# Epoch 1/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0775
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0988
# Epoch 3/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0996
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0996
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0996
# Generator training - Iteration - 35
# 580/580 [==============================] - 132s 227ms/step - loss: -0.0765 - functional_25_loss: 0.0228 - functional_27_loss: -0.0993
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 36
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0794
# Epoch 2/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0994
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0998
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0997
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0998
# Generator training - Iteration - 36
# 580/580 [==============================] - 132s 227ms/step - loss: -0.0769 - functional_25_loss: 0.0226 - functional_27_loss: -0.0995
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 37
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0762
# Epoch 2/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0991
# Epoch 3/5
# 580/580 [==============================] - 32s 56ms/step - loss: -0.0995
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0994
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0995
# Generator training - Iteration - 37
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0770 - functional_25_loss: 0.0224 - functional_27_loss: -0.0994
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 38
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0882
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0985
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0993
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0993
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0993
# Generator training - Iteration - 38
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0771 - functional_25_loss: 0.0222 - functional_27_loss: -0.0992
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 39
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0798
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0969
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0983
# Epoch 4/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0987
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0992
# Generator training - Iteration - 39
# 580/580 [==============================] - 131s 227ms/step - loss: -0.0776 - functional_25_loss: 0.0219 - functional_27_loss: -0.0995
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 40
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0728
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0971
# Epoch 3/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0986
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0984
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0989
# Generator training - Iteration - 40
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0777 - functional_25_loss: 0.0217 - functional_27_loss: -0.0994
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 41
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0502
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0957
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0984
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0986
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0990
# Generator training - Iteration - 41
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0773 - functional_25_loss: 0.0216 - functional_27_loss: -0.0989
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 42
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0833
# Epoch 2/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0985
# Epoch 3/5
# 580/580 [==============================] - 32s 56ms/step - loss: -0.0990
# Epoch 4/5
# 580/580 [==============================] - 32s 56ms/step - loss: -0.0995
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0993
# Generator training - Iteration - 42
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0785 - functional_25_loss: 0.0211 - functional_27_loss: -0.0996
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 43
# Epoch 1/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0539
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0960
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0986
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0993
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0993
# Generator training - Iteration - 43
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0786 - functional_25_loss: 0.0212 - functional_27_loss: -0.0997
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 44
# Epoch 1/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0795
# Epoch 2/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0971
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0980
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0985
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0986
# Generator training - Iteration - 44
# 580/580 [==============================] - 131s 227ms/step - loss: -0.0776 - functional_25_loss: 0.0212 - functional_27_loss: -0.0988
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 45
# Epoch 1/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0482
# Epoch 2/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0978
# Epoch 3/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0987
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0995
# Epoch 5/5
# 580/580 [==============================] - 32s 56ms/step - loss: -0.0997
# Generator training - Iteration - 45
# 580/580 [==============================] - 133s 229ms/step - loss: -0.0768 - functional_25_loss: 0.0209 - functional_27_loss: -0.0977
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 46
# Epoch 1/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0768
# Epoch 2/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0974
# Epoch 3/5
# 580/580 [==============================] - 32s 56ms/step - loss: -0.0984
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0985
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0990
# Generator training - Iteration - 46
# 580/580 [==============================] - 132s 228ms/step - loss: -0.0783 - functional_25_loss: 0.0208 - functional_27_loss: -0.0991
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 47
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0775
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0974
# Epoch 3/5
# 580/580 [==============================] - 34s 58ms/step - loss: -0.0991
# Epoch 4/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0993
# Epoch 5/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0998
# Generator training - Iteration - 47
# 580/580 [==============================] - 131s 227ms/step - loss: -0.0778 - functional_25_loss: 0.0210 - functional_27_loss: -0.0988
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 48
# Epoch 1/5
# 580/580 [==============================] - 33s 58ms/step - loss: -0.0738
# Epoch 2/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0994
# Epoch 3/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0997
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0999
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0999
# Generator training - Iteration - 48
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0786 - functional_25_loss: 0.0203 - functional_27_loss: -0.0990
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 49
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0717
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0968
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0987
# Epoch 4/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0990
# Epoch 5/5
# 580/580 [==============================] - 33s 56ms/step - loss: -0.0994
# Generator training - Iteration - 49
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0786 - functional_25_loss: 0.0204 - functional_27_loss: -0.0991
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets
# Discriminator training - Iteration - 50
# Epoch 1/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0802
# Epoch 2/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0962
# Epoch 3/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0984
# Epoch 4/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0992
# Epoch 5/5
# 580/580 [==============================] - 33s 57ms/step - loss: -0.0995
# Generator training - Iteration - 50
# 580/580 [==============================] - 131s 226ms/step - loss: -0.0783 - functional_25_loss: 0.0205 - functional_27_loss: -0.0988
# INFO:tensorflow:Assets written to: C:\Users\user\Desktop\segan_model_7\assets

# %%
out = generator.predict(speech_test)

# %%
def butter_lowpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
index = 52

print("input speech")
plt.plot(speech_test[index])
plt.show()
print("actual egg")
plt.plot(egg_test[index])
plt.show()
print("smoothed generator egg")
plt.plot(butter_lowpass_filter(out[index,:,0], cutoff = 500, fs = 22050, order = 6))
plt.show()
# Out:
# input speech
# actual egg
# smoothed generator egg
