# %%
from segan_utils import *
from train_gan import *

# %%
gen = Generator().construct()
gen.summary()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-2-7aa9f6ac2063> in <module>
# ----> 1 gen = Generator().construct()
#       2 gen.summary()
#
# ~/Documents/Python Scripts/SAP Project/Glottal-Instants-Extraction/segan_utils.py in construct(self, input_shape, batch_size)
#      62         inp = layers.Input(shape = input_shape, batch_size = batch_size) #Add batch_size parameter
#      63
# ---> 64         b1 = self.gen_block(n_filters = 16, prev_input = inp, block_type = 'conv')
#      65         b2 = self.gen_block(n_filters = 32, prev_input = b1, block_type = 'conv')
#      66         b3 = self.gen_block(n_filters = 32, prev_input = b2, block_type = 'conv')
#
# ~/Documents/Python Scripts/SAP Project/Glottal-Instants-Extraction/segan_utils.py in gen_block(self, n_filters, prev_input, padding, block_type, activation)
# ...

# %%
disc = Discriminator().construct()

# %%
from tensorflow.keras import models, layers

# %%
disc.compile(loss = 'mse', optimizer = 'adam')
disc.trainable = False
gan = models.Sequential([gen, disc])
gan.compile(loss = 'mse', optimizer = 'adam')

# %%
names = load_reals()
# Out:
# 100%|██████████| 3377/3377 [00:03<00:00, 887.68it/s]

# %%
gen, disc = gan.layers
x = generate_fakes(gen, names, batch_size = 40, trim_size = 16384)
# Out:
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-7-2b45831e574f> in <module>
#       1 gen, disc = gan.layers
# ----> 2 x = generate_fakes(gen, names, batch_size = 40, trim_size = 16384)
#
# ~/Documents/Python Scripts/SAP Project/Glottal-Instants-Extraction/train_gan.py in generate_fakes(gen, names, batch_size, trim_size)
#      58     #generate fake samples with generator
#      59     gen_input = generate_inputs(names, batch_size, trim_size)
# ---> 60     return gen.predict(gen_input)
#      61
#      62
#
# ~/anaconda3/envs/machine_learning/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# ...
