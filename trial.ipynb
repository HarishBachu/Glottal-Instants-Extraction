# %%
from segan_utils import *
from train_gan import *

# %%
gen = Generator().construct()
gen.summary()
# Out:
# Model: "Generator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(40, 16384, 1)]     0
# __________________________________________________________________________________________________
# gen_conv_1 (Conv1D)             (40, 8192, 16)       512         input_1[0][0]
# __________________________________________________________________________________________________
# gen_ac_1 (PReLU)                (40, 8192, 16)       131072      gen_conv_1[0][0]
# __________________________________________________________________________________________________
# gen_conv_2 (Conv1D)             (40, 4096, 32)       15904       gen_ac_1[0][0]
# __________________________________________________________________________________________________
# gen_ac_2 (PReLU)                (40, 4096, 32)       131072      gen_conv_2[0][0]
# __________________________________________________________________________________________________
# gen_conv_3 (Conv1D)             (40, 2048, 32)       31776       gen_ac_2[0][0]
# __________________________________________________________________________________________________
# gen_ac_3 (PReLU)                (40, 2048, 32)       65536       gen_conv_3[0][0]
# __________________________________________________________________________________________________
# gen_conv_4 (Conv1D)             (40, 1024, 64)       63552       gen_ac_3[0][0]
# __________________________________________________________________________________________________
# gen_ac_4 (PReLU)                (40, 1024, 64)       65536       gen_conv_4[0][0]
# __________________________________________________________________________________________________
# gen_conv_5 (Conv1D)             (40, 512, 64)        127040      gen_ac_4[0][0]
# __________________________________________________________________________________________________
# gen_ac_5 (PReLU)                (40, 512, 64)        32768       gen_conv_5[0][0]
# __________________________________________________________________________________________________
# gen_conv_6 (Conv1D)             (40, 256, 128)       254080      gen_ac_5[0][0]
# __________________________________________________________________________________________________
# gen_ac_6 (PReLU)                (40, 256, 128)       32768       gen_conv_6[0][0]
# __________________________________________________________________________________________________
# gen_conv_7 (Conv1D)             (40, 128, 128)       508032      gen_ac_6[0][0]
# __________________________________________________________________________________________________
# gen_ac_7 (PReLU)                (40, 128, 128)       16384       gen_conv_7[0][0]
# __________________________________________________________________________________________________
# gen_conv_8 (Conv1D)             (40, 64, 256)        1016064     gen_ac_7[0][0]
# __________________________________________________________________________________________________
# gen_ac_8 (PReLU)                (40, 64, 256)        16384       gen_conv_8[0][0]
# __________________________________________________________________________________________________
# gen_conv_9 (Conv1D)             (40, 32, 256)        2031872     gen_ac_8[0][0]
# __________________________________________________________________________________________________
# gen_ac_9 (PReLU)                (40, 32, 256)        8192        gen_conv_9[0][0]
# __________________________________________________________________________________________________
# gen_conv_10 (Conv1D)            (40, 16, 512)        4063744     gen_ac_9[0][0]
# __________________________________________________________________________________________________
# gen_ac_10 (PReLU)               (40, 16, 512)        8192        gen_conv_10[0][0]
# __________________________________________________________________________________________________
# gen_conv_11 (Conv1D)            (40, 8, 1024)        16253952    gen_ac_10[0][0]
# __________________________________________________________________________________________________
# gen_ac_11 (PReLU)               (40, 8, 1024)        8192        gen_conv_11[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (40, 8, 2048)        0           gen_ac_11[0][0]
# __________________________________________________________________________________________________
# gen_deconv_1 (Conv1DTranspose)  (40, 16, 512)        32506368    concat_layer[0][0]
# __________________________________________________________________________________________________
# gen_ac_12 (PReLU)               (40, 16, 512)        8192        gen_deconv_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (40, 16, 512)        0           gen_ac_10[0][0]
#                                                                  gen_ac_12[0][0]
# __________________________________________________________________________________________________
# gen_deconv_2 (Conv1DTranspose)  (40, 32, 256)        4063488     add[0][0]
# __________________________________________________________________________________________________
# gen_ac_13 (PReLU)               (40, 32, 256)        8192        gen_deconv_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (40, 32, 256)        0           gen_ac_9[0][0]
#                                                                  gen_ac_13[0][0]
# __________________________________________________________________________________________________
# gen_deconv_3 (Conv1DTranspose)  (40, 64, 256)        2031872     add_1[0][0]
# __________________________________________________________________________________________________
# gen_ac_14 (PReLU)               (40, 64, 256)        16384       gen_deconv_3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (40, 64, 256)        0           gen_ac_8[0][0]
#                                                                  gen_ac_14[0][0]
# __________________________________________________________________________________________________
# gen_deconv_4 (Conv1DTranspose)  (40, 128, 128)       1015936     add_2[0][0]
# __________________________________________________________________________________________________
# gen_ac_15 (PReLU)               (40, 128, 128)       16384       gen_deconv_4[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (40, 128, 128)       0           gen_ac_7[0][0]
#                                                                  gen_ac_15[0][0]
# __________________________________________________________________________________________________
# gen_deconv_5 (Conv1DTranspose)  (40, 256, 128)       508032      add_3[0][0]
# __________________________________________________________________________________________________
# gen_ac_16 (PReLU)               (40, 256, 128)       32768       gen_deconv_5[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (40, 256, 128)       0           gen_ac_6[0][0]
#                                                                  gen_ac_16[0][0]
# __________________________________________________________________________________________________
# gen_deconv_6 (Conv1DTranspose)  (40, 512, 64)        254016      add_4[0][0]
# __________________________________________________________________________________________________
# gen_ac_17 (PReLU)               (40, 512, 64)        32768       gen_deconv_6[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (40, 512, 64)        0           gen_ac_5[0][0]
#                                                                  gen_ac_17[0][0]
# __________________________________________________________________________________________________
# gen_deconv_7 (Conv1DTranspose)  (40, 1024, 64)       127040      add_5[0][0]
# __________________________________________________________________________________________________
# gen_ac_18 (PReLU)               (40, 1024, 64)       65536       gen_deconv_7[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (40, 1024, 64)       0           gen_ac_4[0][0]
#                                                                  gen_ac_18[0][0]
# __________________________________________________________________________________________________
# gen_deconv_8 (Conv1DTranspose)  (40, 2048, 32)       63520       add_6[0][0]
# __________________________________________________________________________________________________
# gen_ac_19 (PReLU)               (40, 2048, 32)       65536       gen_deconv_8[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (40, 2048, 32)       0           gen_ac_3[0][0]
#                                                                  gen_ac_19[0][0]
# __________________________________________________________________________________________________
# gen_deconv_9 (Conv1DTranspose)  (40, 4096, 32)       31776       add_7[0][0]
# __________________________________________________________________________________________________
# gen_ac_20 (PReLU)               (40, 4096, 32)       131072      gen_deconv_9[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (40, 4096, 32)       0           gen_ac_2[0][0]
#                                                                  gen_ac_20[0][0]
# __________________________________________________________________________________________________
# gen_deconv_10 (Conv1DTranspose) (40, 8192, 16)       15888       add_8[0][0]
# __________________________________________________________________________________________________
# gen_ac_21 (PReLU)               (40, 8192, 16)       131072      gen_deconv_10[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (40, 8192, 16)       0           gen_ac_1[0][0]
#                                                                  gen_ac_21[0][0]
# __________________________________________________________________________________________________
# gen_deconv_11 (Conv1DTranspose) (40, 16384, 1)       497         add_9[0][0]
# __________________________________________________________________________________________________
# gen_ac_22 (Activation)          (40, 16384, 1)       0           gen_deconv_11[0][0]
# ==================================================================================================
# Total params: 66,008,961
# Trainable params: 66,008,961
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
disc = Discriminator().construct()

# %%
from tensorflow.keras import models, layers

# %%
disc.compile(loss = 'mse', optimizer = 'adam')
disc.trainable = False
gan = models.Sequential([gen, disc])
gan.compile(loss = 'mse', optimizer = 'adam')

# %%
names = load_reals()
# Out:
# 100%|██████████| 3377/3377 [00:03<00:00, 881.97it/s]

# %%
gen, disc = gan.layers
x = generate_fakes(gen, names, batch_size = 40, trim_size = 16384)
# Out:
# (40, 16384, 1)
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-7-2b45831e574f> in <module>
#       1 gen, disc = gan.layers
# ----> 2 x = generate_fakes(gen, names, batch_size = 40, trim_size = 16384)
#
# ~/Documents/Python Scripts/SAP Project/Glottal-Instants-Extraction/train_gan.py in generate_fakes(gen, names, batch_size, trim_size)
#      72     #newar = np.asarray(gen_input).astype('float32')
#      73     #y = gen.predict(gen_input)
# ---> 74     y = gen(gen_input)
#      75     return y
#      76
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1010         with autocast_variable.enable_auto_cast_variables(
#    1011             self._compute_dtype_object):
# -> 1012           outputs = call_fn(inputs, *args, **kwargs)
#    1013
#    1014         if self._activity_regularizer:
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in call(self, inputs, training, mask)
#     422         a list of tensors if there are more than one outputs.
#     423     """
# --> 424     return self._run_internal_graph(
#     425         inputs, training=training, mask=mask)
#     426
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     558
#     559         args, kwargs = node.map_arguments(tensor_dict)
# --> 560         outputs = node.layer(*args, **kwargs)
#     561
#     562         # Update tensor_dict.
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1010         with autocast_variable.enable_auto_cast_variables(
#    1011             self._compute_dtype_object):
# -> 1012           outputs = call_fn(inputs, *args, **kwargs)
#    1013
#    1014         if self._activity_regularizer:
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/keras/layers/convolutional.py in call(self, inputs)
#     246       inputs = array_ops.pad(inputs, self._compute_causal_padding(inputs))
#     247
# --> 248     outputs = self._convolution_op(inputs, self.kernel)
#     249
#     250     if self.use_bias:
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1011     dilations=None,
#    1012     name=None):
# -> 1013   return convolution_internal(
#    1014       input,  # pylint: disable=redefined-builtin
#    1015       filters,
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1141         op = conv1d
#    1142
# -> 1143       return op(
#    1144           input,
#    1145           filters,
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     603                   func.__module__, arg_name, arg_value, 'in a future version'
#     604                   if date is None else ('after %s' % date), instructions)
# --> 605       return func(*args, **kwargs)
#     606
#     607     doc = _add_deprecated_arg_value_notice_to_docstring(
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     603                   func.__module__, arg_name, arg_value, 'in a future version'
#     604                   if date is None else ('after %s' % date), instructions)
# --> 605       return func(*args, **kwargs)
#     606
#     607     doc = _add_deprecated_arg_value_notice_to_docstring(
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in conv1d(value, filters, stride, padding, use_cudnn_on_gpu, data_format, name, input, dilations)
#    1883     filters = array_ops.expand_dims(filters, 0)
#    1884     if value.shape.ndims in (4, 3, 2, 1, 0, None):
# -> 1885       result = gen_nn_ops.conv2d(
#    1886           value,
#    1887           filters,
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     930       return _result
#     931     except _core._NotOkStatusException as e:
# --> 932       _ops.raise_from_not_ok_status(e, name)
#     933     except _core._FallbackException:
#     934       pass
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6860   message = e.message + (" name: " + name if name is not None else "")
#    6861   # pylint: disable=protected-access
# -> 6862   six.raise_from(core._status_to_exception(e.code, message), None)
#    6863   # pylint: enable=protected-access
#    6864
#
# ~/anaconda3/envs/machine_learning/lib/python3.8/site-packages/six.py in raise_from(value, from_value)
#
# NotFoundError: No algorithm worked! [Op:Conv2D]
